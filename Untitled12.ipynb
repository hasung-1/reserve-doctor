# %%
Time.objects.all()
# Out:
# <QuerySet [<Time: 00:00:00>, <Time: 00:00:00>, <Time: 06:00:00>, <Time: 09:54:03>, <Time: 18:00:00>]>

# %%
Reserve.objects.filter(date='2018/02/1')
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-2-abb4e443c582> in <module>()
# ----> 1 Reserve.objects.filter(date='2018/02/1')
#
# C:\Users\yoonh\AppData\Local\Programs\Python\Python36\lib\site-packages\django\db\models\manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# C:\Users\yoonh\AppData\Local\Programs\Python\Python36\lib\site-packages\django\db\models\query.py in filter(self, *args, **kwargs)
#     782         set.
#     783         """
# --> 784         return self._filter_or_exclude(False, *args, **kwargs)
#     785
# ...
